# %% [markdown]
# # Task 2
# ## Вывод виде таблицы ФИО и среднеарифметическую оценку по всем предметам по зачетке

# %%
import pandas as pd
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_9076\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel("test-subjects.xlsx")

df
# Out:
#     Номер по списку                           ФИО Дата рождения  № Зачетки  \
# 0               1.0  Картунчиков Артем Максимович    2002-02-19     239344
# 1               NaN  Картунчиков Артем Максимович           NaT     239344
# 2               NaN  Картунчиков Артем Максимович           NaT     239344
# 3               2.0   Стрыбак Вячеслав Валерьевич    2002-02-20     240420
# 4               NaN   Стрыбак Вячеслав Валерьевич           NaT     240420
# 5               NaN   Стрыбак Вячеслав Валерьевич           NaT     240420
# 6               NaN   Стрыбак Вячеслав Валерьевич           NaT     240420
# 7               NaN   Стрыбак Вячеслав Валерьевич           NaT     240420
# 8               3.0     Сердюков Матвей Романович    2002-02-21     241496
# 9               NaN     Сердюков Матвей Романович           NaT     241496
# 10              NaN     Сердюков Матвей Романович           NaT     241496
# 11              NaN     Сердюков Матвей Романович           NaT     241496
#
#                         Предметы        Дата экзамена  Оценка
# 0   Гибкое управление проектами   2075-08-21 00:00:00       5
# 1            Системы мониторинга  1998-05-19 00:00:00       4
# 2   Технологии личностного роста  2001-06-28 00:00:00       3
# 3   Гибкое управление проектами   2075-08-21 00:00:00       4
# 4   Технологии личностного роста  2001-06-29 00:00:00       4
# 5              Гражданское право  2012-01-16 00:00:00       4
# 6                 Кузнечное дело  2000-10-09 00:00:00       5
# 7                   Русский язык  2002-04-08 00:00:00       5
# 8                 Кузнечное дело  2000-10-09 00:00:00       3
# 9            Системы мониторинга  1998-05-19 00:00:00       3
# 10        Паронормальные явления           32.13.0000       4
# 11                    Гимнастика  2001-11-09 00:00:00       5

# %%
average_grades = df.groupby('ФИО')['Оценка'].mean()

# %%
print(average_grades)
# Out:
# ФИО
# Картунчиков Артем Максимович    4.00
# Сердюков Матвей Романович       3.75
# Стрыбак Вячеслав Валерьевич     4.40
# Name: Оценка, dtype: float64
